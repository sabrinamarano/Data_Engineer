# %% [markdown]
# <h1>CITIES TABLES</h1>

# %%
city=['berlin','paris','barcelona']
iso=['DE','FR','ES']
city_iso=['berlin_DE', 'paris_FR', 'barcelona_ES']
cities=pd.DataFrame({'city':city, 'iso':iso, 'city_iso':city_iso})

# %%
cities.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   city      3 non-null      object
#  1   iso       3 non-null      object
#  2   city_iso  3 non-null      object
# dtypes: object(3)
# memory usage: 200.0+ bytes

# %% [markdown]
# <h1>POPULATION DATA</h1>

# %% [markdown]
# <h>WEB SCRAPING</h>

# %% [markdown]
# <h><strong>POPULATION DATA PARIS</strong></h>

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %%
url = "https://ugeo.urbistat.com/AdminStat/en/fr/demografia/eta/paris/75/3"

# %%
response =requests.get(url)

# %%
response.status_code
# Out:
# 500

# %%
soup = BeautifulSoup(response.content, "html.parser")

# %%
table =soup.select_one("table.table_result_light")

age_range=[]
for i in range(len(table.select('td.table_label'))):
    age_range.append(table.select('td.table_label')[i].get_text())

age_range=pd.DataFrame({"age_range":age_range})
age_range.replace(to_replace=[r"\\t|\\n|\\r", "\t|\n|\r"], value=["",""], regex=True, inplace=True)

values=[]
for i in range(len(table.select("td"))):
    values.append(table.select("td")[i].get_text())

values=pd.DataFrame({"value":values})
values.replace(to_replace=[r"\\t|\\n|\\r", "\t|\n|\r"], value=["",""], regex=True, inplace=True)
values.replace(to_replace=[",", ""], value=["",""], regex=True, inplace=True)

tot_pop =values.loc[[9,16,23,30,37,44,51,58,65,72,79]]

tot_pop['perc'] = [3,3,5,5,7,17,14,13,13,9,10]
tot_pop['city']='paris'

tot_pop=tot_pop.reset_index()
tot_pop=tot_pop.drop('index', axis=1)
population_paris=age_range.join(tot_pop, how="inner")

# %%
population_paris['city_iso']= 'paris_FR'

# %%
population_paris
# Out:
#       age_range   value  perc   city  city_iso
# 0     0 - 2 age   65309     3  paris  paris_FR
# 1     3 - 5 age   59827     3  paris  paris_FR
# 2    6 - 11 age  119576     5  paris  paris_FR
# 3   12 - 17 age  118412     5  paris  paris_FR
# 4   18 - 24 age  229742     7  paris  paris_FR
# 5   25 - 34 age  408704    17  paris  paris_FR
# 6   35 - 44 age  301547    14  paris  paris_FR
# 7   45 - 54 age  278738    13  paris  paris_FR
# 8   55 - 64 age  240245    13  paris  paris_FR
# 9   65 - 74 age  195095     9  paris  paris_FR
# 10     75 e più  170331    10  paris  paris_FR

# %% [markdown]
# <h><strong>POPULATION DATA BERLIN</strong></h>

# %%
url = "https://ugeo.urbistat.com/AdminStat/en/de/demografia/eta/berlin/11/3"

# %%
response =requests.get(url)

# %%
response.status_code
# Out:
# 200

# %%
soup = BeautifulSoup(response.content, "html.parser")

# %%
table =soup.select_one("table.table_result_light")

age_range=[]
for i in range(len(table.select('td.table_label'))):
    age_range.append(table.select('td.table_label')[i].get_text())

age_range=pd.DataFrame({"age_range":age_range})
age_range.replace(to_replace=[r"\\t|\\n|\\r", "\t|\n|\r"], value=["",""], regex=True, inplace=True)

values=[]
for i in range(len(table.select("td"))):
    values.append(table.select("td")[i].get_text())

values=pd.DataFrame({"value":values})
values.replace(to_replace=[r"\\t|\\n|\\r", "\t|\n|\r"], value=["",""], regex=True, inplace=True)
values.replace(to_replace=[",", ""], value=["",""], regex=True, inplace=True)

tot_pop =values.loc[[9,16,23,30,37,44,51,58,65,72,79]]

tot_pop['perc'] = [3,3,5,5,7,17,14,13,13,9,10]
tot_pop['city']='berlin'

tot_pop=tot_pop.reset_index()
tot_pop=tot_pop.drop('index', axis=1)
population_berlin=age_range.join(tot_pop, how="inner")

# %%
population_berlin['city_iso']= 'berlin_DE'

# %%
population_berlin
# Out:
#       age_range   value  perc    city   city_iso
# 0     0 - 2 age  116834     3  berlin  berlin_DE
# 1     3 - 5 age  112940     3  berlin  berlin_DE
# 2    6 - 11 age  196587     5  berlin  berlin_DE
# 3   12 - 17 age  179513     5  berlin  berlin_DE
# 4   18 - 24 age  264084     7  berlin  berlin_DE
# 5   25 - 34 age  613696    17  berlin  berlin_DE
# 6   35 - 44 age  530715    14  berlin  berlin_DE
# 7   45 - 54 age  482906    13  berlin  berlin_DE
# 8   55 - 64 age  466691    13  berlin  berlin_DE
# 9   65 - 74 age  325994     9  berlin  berlin_DE
# 10     75 e più  379531    10  berlin  berlin_DE

# %% [markdown]
# <h><strong>POPULATION DATA BARCELONA</strong></h>

# %%
url = "https://ugeo.urbistat.com/AdminStat/en/es/demografia/eta/barcelona/8/3"
response =requests.get(url)
response.status_code
soup = BeautifulSoup(response.content, "html.parser")

# %%
table =soup.select_one("table.table_result_light")

age_range=[]
for i in range(len(table.select('td.table_label'))):
    age_range.append(table.select('td.table_label')[i].get_text())

age_range=pd.DataFrame({"age_range":age_range})
age_range.replace(to_replace=[r"\\t|\\n|\\r", "\t|\n|\r"], value=["",""], regex=True, inplace=True)

values=[]
for i in range(len(table.select("td"))):
    values.append(table.select("td")[i].get_text())

values=pd.DataFrame({"value":values})
values.replace(to_replace=[r"\\t|\\n|\\r", "\t|\n|\r"], value=["",""], regex=True, inplace=True)
values.replace(to_replace=[",", ""], value=["",""], regex=True, inplace=True)

tot_pop =values.loc[[9,16,23,30,37,44,51,58,65,72,79]]

tot_pop['perc'] = [2,3,6,6,7,12,16,16,12,10,9]
tot_pop['city']='barcelona'

tot_pop=tot_pop.reset_index()
tot_pop=tot_pop.drop('index', axis=1)
population_barcelona=age_range.join(tot_pop, how="inner")
population_barcelona['city_iso']= 'barcelona_ES'

# %%
population_barcelona
# Out:
#       age_range   value  perc       city      city_iso
# 0     0 - 2 age  141646     2  barcelona  barcelona_ES
# 1     3 - 5 age  161953     3  barcelona  barcelona_ES
# 2    6 - 11 age  360186     6  barcelona  barcelona_ES
# 3   12 - 17 age  363824     6  barcelona  barcelona_ES
# 4   18 - 24 age  409829     7  barcelona  barcelona_ES
# 5   25 - 34 age  693809    12  barcelona  barcelona_ES
# 6   35 - 44 age  915718    16  barcelona  barcelona_ES
# 7   45 - 54 age  903528    16  barcelona  barcelona_ES
# 8   55 - 64 age  705570    12  barcelona  barcelona_ES
# 9   65 - 74 age  547627    10  barcelona  barcelona_ES
# 10     75 e più  539712     9  barcelona  barcelona_ES

# %% [markdown]
# <h1>POPULATION CITIES</h1>

# %%
population_cities=population_paris.append([population_berlin,population_barcelona]).reset_index()
population_cities=population_cities.drop('index', axis=1)

# %%
population_cities['value']=population_cities['value'].astype(int)

# %%
population_cities.head(50)
# Out:
#       age_range   value  perc       city      city_iso
# 0     0 - 2 age   65309     3      paris      paris_FR
# 1     3 - 5 age   59827     3      paris      paris_FR
# 2    6 - 11 age  119576     5      paris      paris_FR
# 3   12 - 17 age  118412     5      paris      paris_FR
# 4   18 - 24 age  229742     7      paris      paris_FR
# 5   25 - 34 age  408704    17      paris      paris_FR
# 6   35 - 44 age  301547    14      paris      paris_FR
# 7   45 - 54 age  278738    13      paris      paris_FR
# 8   55 - 64 age  240245    13      paris      paris_FR
# 9   65 - 74 age  195095     9      paris      paris_FR
# 10     75 e più  170331    10      paris      paris_FR
# 11    0 - 2 age  116834     3     berlin     berlin_DE
# 12    3 - 5 age  112940     3     berlin     berlin_DE
# 13   6 - 11 age  196587     5     berlin     berlin_DE
# 14  12 - 17 age  179513     5     berlin     berlin_DE
# 15  18 - 24 age  264084     7     berlin     berlin_DE
# 16  25 - 34 age  613696    17     berlin     berlin_DE
# 17  35 - 44 age  530715    14     berlin     berlin_DE
# 18  45 - 54 age  482906    13     berlin     berlin_DE
# 19  55 - 64 age  466691    13     berlin     berlin_DE
# 20  65 - 74 age  325994     9     berlin     berlin_DE
# 21     75 e più  379531    10     berlin     berlin_DE
# 22    0 - 2 age  141646     2  barcelona  barcelona_ES
# 23    3 - 5 age  161953     3  barcelona  barcelona_ES
# 24   6 - 11 age  360186     6  barcelona  barcelona_ES
# 25  12 - 17 age  363824     6  barcelona  barcelona_ES
# 26  18 - 24 age  409829     7  barcelona  barcelona_ES
# 27  25 - 34 age  693809    12  barcelona  barcelona_ES
# 28  35 - 44 age  915718    16  barcelona  barcelona_ES
# 29  45 - 54 age  903528    16  barcelona  barcelona_ES
# 30  55 - 64 age  705570    12  barcelona  barcelona_ES
# 31  65 - 74 age  547627    10  barcelona  barcelona_ES
# 32     75 e più  539712     9  barcelona  barcelona_ES

# %%
population_cities.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33 entries, 0 to 32
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age_range  33 non-null     object
#  1   value      33 non-null     int64
#  2   perc       33 non-null     int64
#  3   city       33 non-null     object
#  4   city_iso   33 non-null     object
# dtypes: int64(2), object(3)
# memory usage: 1.4+ KB

# %% [markdown]
# <h1> FLIGHTS DATA</h1>

# %% [markdown]
# <h>API</h>

# %%
from IPython.display import JSON

# %%
from keys import *

# %% [markdown]
# <h1>BERLIN FLIGHTS DATA</h1>

# %%
import requests

url = "https://aerodatabox.p.rapidapi.com/flights/airports/icao/EDDB/2021-11-25T08:00/2021-11-25T20:00"

querystring = {"withLeg":"true","direction":"Arrival","withCancelled":"true","withCodeshared":"true","withCargo":"true","withPrivate":"true","withLocation":"true"}

headers = {
    'x-rapidapi-host': "aerodatabox.p.rapidapi.com",
    'x-rapidapi-key': api_key
    }

response = requests.request("GET", url, headers=headers, params=querystring)

print(response.text)
# Out:
# {"arrivals":[{"departure":{"airport":{"icao":"LYBE","iata":"BEG","name":"Belgrade"},"scheduledTimeLocal":"2021-11-25 07:10+01:00","scheduledTimeUtc":"2021-11-25 06:10Z","terminal":"2","quality":["Basic"]},"arrival":{"scheduledTimeLocal":"2021-11-25 09:00+01:00","actualTimeLocal":"2021-11-25 08:43+01:00","runwayTimeLocal":"2021-11-25 08:42+01:00","scheduledTimeUtc":"2021-11-25 08:00Z","actualTimeUtc":"2021-11-25 07:43Z","runwayTimeUtc":"2021-11-25 07:42Z","terminal":"1","runway":"25R","quality":["Basic","Live"]},"number":"JU 350","callSign":"ASL48J","status":"Arrived","codeshareStatus":"IsOperator","isCargo":false,"aircraft":{"reg":"YU-APE","modeS":"4C01E4","model":"Airbus A319"},"airline":{"name":"Air Serbia"}},{"departure":{"airport":{"icao":"LSZH","iata":"ZRH","name":"Zurich"},"scheduledTimeLocal":"2021-11-25 07:15+01:00","actualTimeLocal":"2021-11-25 07:15+01:00","runwayTimeLocal":"2021-11-25 07:23+01:00","scheduledTimeUtc":"2021-11-25 06:15Z","actualTimeUtc":"2021-11-25 06:15Z","runwayTimeUtc":"2021-11-25 06:23Z","checkInDesk":"1","gate":"A75","quality":["Basic","Live"]},"arrival":{"scheduledTimeLocal":"2021-11-25 08:45+01:00","actualTimeLocal":"2021-11-25 08:32+01:00","runwayTimeLocal":"2021-11-25 08:32+01:00","scheduledTimeUtc":"2021-11-25 07:45Z","actualTimeUtc":"2021-11-25 07:32Z","runwayTimeUtc":"2021-11-25 07:32Z","terminal":"1","runway":"25R","quality":["Basic","Live"]},"number":"LX 974","callSign":"SWR97Y","status":"Arrived","codeshareStatus":"IsOperator","isCargo":false,"aircraft":{"reg":"HB-JLT","modeS":"4B18F5","model":"Airbus A320-200 (Sharklets)"},"airline":{"name":"SWISS"}},{"departure":{"airport":{"icao":"LFPO","iata":"ORY","name":"Paris"},"scheduledTimeLocal":"2021-11-25 07:00+01:00","runwayTimeLocal":"2021-11-25 07:04+01:00","scheduledTimeUtc":"2021-11-25 06:00Z","runwayTimeUtc":"2021-11-25 06:04Z","terminal":"3","runway":"08","quality":["Basic"]},"arrival":{"scheduledTimeLocal":"2021-11-25 08:55+01:00","actualTimeLocal":"2021-11-25 08:32+01:00","runwayTimeLocal":"2021-11-25 08:29+01:00","scheduledTimeUtc":"2021-11-25 07:55Z","actualTimeUtc":"2021-11-25 07:32Z","runwayTimeUtc":"2021-11-25 07:29Z","terminal":"1","runway":"25R","quality":["Basic","Live"]},"number":"AF 7354","callSign":"AFR67SD","status":"Arrived","codeshareStatus":"IsOperator","isCargo":false,"aircraft":{"reg":"F-HBNF","modeS":"3985A5","model":"Airbus A320-100/200"},"airline":{"name":"Air France"}},{"departure":{"airport":{"icao":"LOWW","iata":"VIE","name":"Vienna"},"scheduledTimeLocal":"2021-11-25 07:40+01:00","actualTimeLocal":"2021-11-25 07:46+01:00","runwayTimeLocal":"2021-11-25 07:48+01:00","scheduledTimeUtc":"2021-11-25 06:40Z","actualTimeUtc":"2021-11-25 06:46Z","runwayTimeUtc":"2021-11-25 06:48Z","terminal":"T3","checkInDesk":"351-378","gate":"F23","runway":"16","quality":["Basic","Live"]},"arrival":{"scheduledTimeLocal":"2021-11-25 08:55+01:00","actualTimeLocal":"2021-11-25 08:47+01:00","runwayTimeLocal":"2021-11-25 08:47+01:00","scheduledTimeUtc":"2021-11-25 07:55Z","actualTimeUtc":"2021-11-25 07:47Z","runwayTimeUtc":"2021-11-25 07:47Z","terminal":"1","runway":"25R","quality":["Basic","Live"]},"number":"OS 223","callSign":"AUA223","status":"Arrived","codeshareStatus":"IsOperator","isCargo":false,"aircraft":{"reg":"OE-LWP","modeS":"44082C","model":"Embraer EMB 195"},"airline":{"name":"Austrian"}},{"departure":{"airport":{"icao":"EDDF","iata":"FRA","name":"Frankfurt-am-Main"},"scheduledTimeLocal":"2021-11-25 07:45+01:00","actualTimeLocal":"2021-11-25 07:45+01:00","runwayTimeLocal":"2021-11-25 07:52+01:00","scheduledTimeUtc":"2021-11-25 06:45Z","actualTimeUtc":"2021-11-25 06:45Z","runwayTimeUtc":"2021-11-25 06:52Z","terminal":"1","checkInDesk":"263-453","gate":"A16","runway":"25C","quality":["Basic","Live"]},"arrival":{"scheduledTimeLocal":"2021-11-25 08:55+01:00","actualTimeLocal":"2021-11-25 08:49+01:00","runwayTimeLocal":"2021-11-25 08:47+01:00","scheduledTimeUtc":"2021-11-25 07:55Z","actualTimeUtc":"2021-11-25 07:49Z","runwayTimeU ...

# %%
JSON(response.json())

# %%
flight_data =response.json()

# %%
flight_data['arrivals'][0]['departure']['airport']['name']
# identify arrival time
flight_data['arrivals'][0]['arrival']['scheduledTimeLocal']
#identify airline name
flight_data['arrivals'][0]['airline']['name']
# Out:
# 'Air Serbia'

# %%
departure=[]
arrival_time=[]
airline=[]
for i in range(len(flight_data['arrivals'])):
    departure.append(flight_data['arrivals'][i]['departure']['airport']['name'])
    arrival_time.append(flight_data['arrivals'][i]['arrival']['scheduledTimeLocal'][10:-6])
    airline.append(flight_data['arrivals'][i]['airline']['name'])

# %%
flight_data_berlin=pd.DataFrame({'city':'berlin','airport_departure':departure,'airline':airline,'arrival_time':arrival_time,'city_iso':'berlin_DE'})
flight_data_berlin
# Out:
#        city  airport_departure               airline arrival_time   city_iso
# 0    berlin           Belgrade            Air Serbia        09:00  berlin_DE
# 1    berlin             Zurich                 SWISS        08:45  berlin_DE
# 2    berlin              Paris            Air France        08:55  berlin_DE
# 3    berlin             Vienna              Austrian        08:55  berlin_DE
# 4    berlin  Frankfurt-am-Main             Lufthansa        08:55  berlin_DE
# ..      ...                ...                   ...          ...        ...
# 165  berlin  Frankfurt-am-Main             Lufthansa        19:55  berlin_DE
# 166  berlin          Amsterdam               easyJet        18:10  berlin_DE
# 167  berlin         Luxembourg                Luxair        20:10  berlin_DE
# 168  berlin          Reykjavik  Ghodawat Enterprises        20:00  berlin_DE
# 169  berlin             Munich             Lufthansa        18:10  berlin_DE
#
# [170 rows x 5 columns]

# %%
flight_data_berlin.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 170 entries, 0 to 169
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   city               170 non-null    object
#  1   airport_departure  170 non-null    object
#  2   airline            170 non-null    object
#  3   arrival_time       170 non-null    object
#  4   city_iso           170 non-null    object
# dtypes: object(5)
# memory usage: 6.8+ KB

# %% [markdown]
# <h1>PARIS FLIGHTS DATA</h1>

# %%
import requests

url = "https://aerodatabox.p.rapidapi.com/flights/airports/icao/LFPG/2021-11-25T08:00/2021-11-25T20:00"

querystring = {"withLeg":"true","direction":"Arrival","withCancelled":"true","withCodeshared":"true","withCargo":"true","withPrivate":"true","withLocation":"false"}

headers = {
    'x-rapidapi-host': "aerodatabox.p.rapidapi.com",
    'x-rapidapi-key': api_key
    }

response = requests.request("GET", url, headers=headers, params=querystring)

print(response.text)
# Out:
# {"arrivals":[{"departure":{"airport":{"icao":"EDDL","iata":"DUS","name":"Duesseldorf"},"scheduledTimeLocal":"2021-11-25 06:45+01:00","runwayTimeLocal":"2021-11-25 06:57+01:00","scheduledTimeUtc":"2021-11-25 05:45Z","runwayTimeUtc":"2021-11-25 05:57Z","terminal":"B","checkInDesk":"192,195","gate":"B74","quality":["Basic"]},"arrival":{"scheduledTimeLocal":"2021-11-25 08:05+01:00","scheduledTimeUtc":"2021-11-25 07:05Z","terminal":"2F","quality":["Basic"]},"number":"AF 1107","status":"Unknown","codeshareStatus":"Unknown","isCargo":false,"aircraft":{"reg":"F-HBXG","model":"Embraer 170"},"airline":{"name":"Air France"}},{"departure":{"airport":{"icao":"KIAD","iata":"IAD","name":"District of Columbia"},"scheduledTimeLocal":"2021-11-24 18:35-05:00","actualTimeLocal":"2021-11-24 19:01-05:00","runwayTimeLocal":"2021-11-24 19:01-05:00","scheduledTimeUtc":"2021-11-24 23:35Z","actualTimeUtc":"2021-11-25 00:01Z","runwayTimeUtc":"2021-11-25 00:01Z","quality":["Basic","Live"]},"arrival":{"scheduledTimeLocal":"2021-11-25 08:05+01:00","runwayTimeLocal":"2021-11-25 08:04+01:00","scheduledTimeUtc":"2021-11-25 07:05Z","runwayTimeUtc":"2021-11-25 07:04Z","terminal":"2E","runway":"09R","quality":["Basic"]},"number":"AF 55","callSign":"AFR055","status":"Arrived","codeshareStatus":"IsOperator","isCargo":false,"aircraft":{"reg":"F-GZND","modeS":"3965A3","model":"Boeing 777-300ER"},"airline":{"name":"Air France"}},{"departure":{"airport":{"icao":"LIMC","iata":"MXP","name":"Milan"},"scheduledTimeLocal":"2021-11-25 06:25+01:00","scheduledTimeUtc":"2021-11-25 05:25Z","terminal":"1","quality":["Basic"]},"arrival":{"scheduledTimeLocal":"2021-11-25 08:05+01:00","scheduledTimeUtc":"2021-11-25 07:05Z","terminal":"2D","quality":["Basic"]},"number":"U2 2777","status":"Unknown","codeshareStatus":"Unknown","isCargo":false,"aircraft":{"model":"Airbus A320"},"airline":{"name":"easyJet"}},{"departure":{"airport":{"icao":"EDDF","iata":"FRA","name":"Frankfurt-am-Main"},"scheduledTimeLocal":"2021-11-25 06:50+01:00","actualTimeLocal":"2021-11-25 06:50+01:00","runwayTimeLocal":"2021-11-25 07:10+01:00","scheduledTimeUtc":"2021-11-25 05:50Z","actualTimeUtc":"2021-11-25 05:50Z","runwayTimeUtc":"2021-11-25 06:10Z","terminal":"1","checkInDesk":"263-453","gate":"A14","runway":"18","quality":["Basic","Live"]},"arrival":{"scheduledTimeLocal":"2021-11-25 08:05+01:00","runwayTimeLocal":"2021-11-25 08:07+01:00","scheduledTimeUtc":"2021-11-25 07:05Z","runwayTimeUtc":"2021-11-25 07:07Z","terminal":"2B","runway":"09R","quality":["Basic"]},"number":"LH 1026","callSign":"DLH22Y","status":"Arrived","codeshareStatus":"IsOperator","isCargo":false,"aircraft":{"reg":"D-AINE","modeS":"3C65C5","model":"Airbus A320 NEO"},"airline":{"name":"Lufthansa"}},{"departure":{"airport":{"name":"Clermont-Ferrand"},"quality":[]},"arrival":{"scheduledTimeLocal":"2021-11-25 08:10+01:00","scheduledTimeUtc":"2021-11-25 07:10Z","terminal":"2F","quality":["Basic"]},"number":"AF 7751","status":"Unknown","codeshareStatus":"Unknown","isCargo":false,"aircraft":{"model":"Embraer 170"},"airline":{"name":"Air France"}},{"departure":{"airport":{"icao":"VVNB","iata":"HAN","name":"Hanoi"},"scheduledTimeLocal":"2021-11-25 01:20+07:00","scheduledTimeUtc":"2021-11-24 18:20Z","terminal":"2","quality":["Basic"]},"arrival":{"scheduledTimeLocal":"2021-11-25 08:00+01:00","runwayTimeLocal":"2021-11-25 08:24+01:00","scheduledTimeUtc":"2021-11-25 07:00Z","runwayTimeUtc":"2021-11-25 07:24Z","terminal":"2E","runway":"09R","quality":["Basic"]},"number":"VN 19","callSign":"HVN19","status":"Arrived","codeshareStatus":"IsOperator","isCargo":false,"aircraft":{"reg":"VN-A863","modeS":"8880E1","model":"Boeing 787"},"airline":{"name":"Vietnam"}},{"departure":{"airport":{"icao":"CYUL","iata":"YUL","name":"Montréal"},"scheduledTimeLocal":"2021-11-24 19:18-05:00","actualTimeLocal":"2021-11-24 19:18-05:00","runwayTimeLocal":"2021-11-24 19:54-05:00","scheduledTimeUtc":"2021-11-25 00:18Z","actualTimeUtc":"2021-11-25 00:18Z","runwayTimeUtc":"2021-11-2 ...

# %%
JSON(response.json())

# %%
flight_data_paris =response.json()

# %%
flight_data_paris['arrivals'][0]['departure']['airport']['name']
flight_data_paris['arrivals'][0]['arrival']['scheduledTimeLocal']
flight_data_paris['arrivals'][0]['airline']['name']
# Out:
# 'Air France'

# %%
departure=[]
arrival_time=[]
airline=[]
for i in range(len(flight_data_paris['arrivals'])):
    departure.append(flight_data_paris['arrivals'][i]['departure']['airport']['name'])
    arrival_time.append(flight_data_paris['arrivals'][i]['arrival']['scheduledTimeLocal'][10:-6])
    airline.append(flight_data_paris['arrivals'][i]['airline']['name'])

# %%
flight_data_paris=pd.DataFrame({'city':'paris','airport_departure':departure,'airline':airline,'arrival_time':arrival_time,'city_iso':'paris_FR'})
flight_data_paris
# Out:
#       city     airport_departure     airline arrival_time  city_iso
# 0    paris           Duesseldorf  Air France        08:05  paris_FR
# 1    paris  District of Columbia  Air France        08:05  paris_FR
# 2    paris                 Milan     easyJet        08:05  paris_FR
# 3    paris     Frankfurt-am-Main   Lufthansa        08:05  paris_FR
# 4    paris      Clermont-Ferrand  Air France        08:10  paris_FR
# ..     ...                   ...         ...          ...       ...
# 325  paris             Barcelona  Air France        20:00  paris_FR
# 326  paris                Zurich       SWISS        18:48  paris_FR
# 327  paris                Lisbon  Air France        19:40  paris_FR
# 328  paris             Marrakech  Air France        20:00  paris_FR
# 329  paris                  Lyon  Air France        20:00  paris_FR
#
# [330 rows x 5 columns]

# %%
flight_data_paris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 424 entries, 0 to 423
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   city               424 non-null    object
#  1   airport_departure  424 non-null    object
#  2   airline            424 non-null    object
#  3   arrival_time       424 non-null    object
#  4   city_iso           424 non-null    object
# dtypes: object(5)
# memory usage: 16.7+ KB

# %% [markdown]
# <h1>BARCELONA FLIGHTS DATA</h1>

# %%
import requests

url = "https://aerodatabox.p.rapidapi.com/flights/airports/icao/LEBL/2021-11-25T08:00/2021-11-25T20:00"

querystring = {"withLeg":"true","direction":"Arrival","withCancelled":"true","withCodeshared":"true","withCargo":"true","withPrivate":"true","withLocation":"false"}

headers = {
    'x-rapidapi-host': "aerodatabox.p.rapidapi.com",
    'x-rapidapi-key': api_key
    }

response = requests.request("GET", url, headers=headers, params=querystring)

print(response.text)
# Out:
# {"arrivals":[{"departure":{"airport":{"icao":"LEPA","iata":"PMI","name":"Palma De Mallorca"},"scheduledTimeLocal":"2021-11-25 07:05+01:00","actualTimeLocal":"2021-11-25 07:16+01:00","scheduledTimeUtc":"2021-11-25 06:05Z","actualTimeUtc":"2021-11-25 06:16Z","terminal":"N","checkInDesk":"086-090","gate":"D94","quality":["Basic","Live"]},"arrival":{"scheduledTimeLocal":"2021-11-25 07:55+01:00","actualTimeLocal":"2021-11-25 08:02+01:00","scheduledTimeUtc":"2021-11-25 06:55Z","actualTimeUtc":"2021-11-25 07:02Z","terminal":"1","quality":["Basic","Live"]},"number":"KL 3350","status":"Arrived","codeshareStatus":"IsCodeshared","isCargo":false,"aircraft":{"model":"Boeing 737-800 (winglets)"},"airline":{"name":"KLM"}},{"departure":{"airport":{"icao":"LEPA","iata":"PMI","name":"Palma De Mallorca"},"scheduledTimeLocal":"2021-11-25 07:05+01:00","actualTimeLocal":"2021-11-25 07:16+01:00","scheduledTimeUtc":"2021-11-25 06:05Z","actualTimeUtc":"2021-11-25 06:16Z","terminal":"N","checkInDesk":"086-090","gate":"D94","quality":["Basic","Live"]},"arrival":{"scheduledTimeLocal":"2021-11-25 07:55+01:00","actualTimeLocal":"2021-11-25 08:02+01:00","scheduledTimeUtc":"2021-11-25 06:55Z","actualTimeUtc":"2021-11-25 07:02Z","terminal":"1","quality":["Basic","Live"]},"number":"DL 6747","status":"Arrived","codeshareStatus":"IsCodeshared","isCargo":false,"aircraft":{"model":"Boeing 737-800 (winglets)"},"airline":{"name":"Delta Air Lines"}},{"departure":{"airport":{"icao":"LEPA","iata":"PMI","name":"Palma De Mallorca"},"scheduledTimeLocal":"2021-11-25 07:05+01:00","actualTimeLocal":"2021-11-25 07:16+01:00","scheduledTimeUtc":"2021-11-25 06:05Z","actualTimeUtc":"2021-11-25 06:16Z","terminal":"N","checkInDesk":"086-090","gate":"D94","quality":["Basic","Live"]},"arrival":{"scheduledTimeLocal":"2021-11-25 07:55+01:00","actualTimeLocal":"2021-11-25 08:02+01:00","scheduledTimeUtc":"2021-11-25 06:55Z","actualTimeUtc":"2021-11-25 07:02Z","terminal":"1","quality":["Basic","Live"]},"number":"JU 7450","status":"Arrived","codeshareStatus":"IsCodeshared","isCargo":false,"aircraft":{"model":"Boeing 737-800 (winglets)"},"airline":{"name":"Air Serbia"}},{"departure":{"airport":{"icao":"LEBB","iata":"BIO","name":"Bilbao"},"scheduledTimeLocal":"2021-11-25 07:00+01:00","scheduledTimeUtc":"2021-11-25 06:00Z","terminal":"1","checkInDesk":"10-16","gate":"11","quality":["Basic"]},"arrival":{"scheduledTimeLocal":"2021-11-25 08:10+01:00","scheduledTimeUtc":"2021-11-25 07:10Z","terminal":"1","quality":["Basic"]},"number":"VY 1423","status":"Arrived","codeshareStatus":"Unknown","isCargo":false,"aircraft":{"model":"Airbus A320"},"airline":{"name":"Vueling"}},{"departure":{"airport":{"icao":"LEPA","iata":"PMI","name":"Palma De Mallorca"},"scheduledTimeLocal":"2021-11-25 07:05+01:00","actualTimeLocal":"2021-11-25 07:16+01:00","scheduledTimeUtc":"2021-11-25 06:05Z","actualTimeUtc":"2021-11-25 06:16Z","terminal":"N","checkInDesk":"086-090","gate":"D94","quality":["Basic","Live"]},"arrival":{"scheduledTimeLocal":"2021-11-25 07:55+01:00","actualTimeLocal":"2021-11-25 08:02+01:00","scheduledTimeUtc":"2021-11-25 06:55Z","actualTimeUtc":"2021-11-25 07:02Z","terminal":"1","quality":["Basic","Live"]},"number":"AF 4819","status":"Arrived","codeshareStatus":"IsCodeshared","isCargo":false,"aircraft":{"model":"Boeing 737-800 (winglets)"},"airline":{"name":"Air France"}},{"departure":{"airport":{"icao":"LEPA","iata":"PMI","name":"Palma De Mallorca"},"scheduledTimeLocal":"2021-11-25 07:05+01:00","actualTimeLocal":"2021-11-25 07:16+01:00","scheduledTimeUtc":"2021-11-25 06:05Z","actualTimeUtc":"2021-11-25 06:16Z","terminal":"N","checkInDesk":"086-090","gate":"D94","quality":["Basic","Live"]},"arrival":{"scheduledTimeLocal":"2021-11-25 07:55+01:00","actualTimeLocal":"2021-11-25 08:02+01:00","scheduledTimeUtc":"2021-11-25 06:55Z","actualTimeUtc":"2021-11-25 07:02Z","terminal":"1","quality":["Basic","Live"]},"number":"EY 4388","status":"Arrived","codeshareStatus":"IsCodeshared","isCargo":false,"aircraft":{" ...

# %%
flight_data_barcelona =response.json()

# %%
departure=[]
arrival_time=[]
airline=[]
for i in range(len(flight_data_barcelona['arrivals'])):
    departure.append(flight_data_barcelona['arrivals'][i]['departure']['airport']['name'])
    arrival_time.append(flight_data_barcelona['arrivals'][i]['arrival']['scheduledTimeLocal'][10:-6])
    airline.append(flight_data_barcelona['arrivals'][i]['airline']['name'])

# %%
flight_data_barcelona=pd.DataFrame({'city':'barcelona','airport_departure':departure,'airline':airline,'arrival_time':arrival_time,'city_iso':'barcelona_ES'})
flight_data_barcelona
# Out:
#           city    airport_departure          airline arrival_time  \
# 0    barcelona    Palma De Mallorca              KLM        07:55
# 1    barcelona    Palma De Mallorca  Delta Air Lines        07:55
# 2    barcelona    Palma De Mallorca       Air Serbia        07:55
# 3    barcelona               Bilbao          Vueling        08:10
# 4    barcelona    Palma De Mallorca       Air France        07:55
# ..         ...                  ...              ...          ...
# 419  barcelona  Gran Canaria Island           Iberia        20:10
# 420  barcelona             Katowice         Wizz Air        19:50
# 421  barcelona            Bucharest         Blue Air        19:50
# 422  barcelona    Frankfurt-am-Main          Ryanair        19:50
# 423  barcelona               Kraków          Ryanair        20:00
#
#          city_iso
# 0    barcelona_ES
# 1    barcelona_ES
# 2    barcelona_ES
# 3    barcelona_ES
# 4    barcelona_ES
# ..            ...
# 419  barcelona_ES
# 420  barcelona_ES
# 421  barcelona_ES
# 422  barcelona_ES
# 423  barcelona_ES
#
# [424 rows x 5 columns]

# %%
flight_data_barcelona.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 424 entries, 0 to 423
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   city               424 non-null    object
#  1   airport_departure  424 non-null    object
#  2   airline            424 non-null    object
#  3   arrival_time       424 non-null    object
#  4   city_iso           424 non-null    object
# dtypes: object(5)
# memory usage: 16.7+ KB

# %% [markdown]
# <h1>Cities ARRIVALS</h1>

# %%
arrivals_cities=flight_data_berlin.append([flight_data_paris,flight_data_barcelona]).reset_index()
arrivals_cities=arrivals_cities.drop('index', axis=1)
arrivals_cities
# Out:
#           city    airport_departure     airline arrival_time      city_iso
# 0       berlin             Belgrade  Air Serbia        09:00     berlin_DE
# 1       berlin               Zurich       SWISS        08:45     berlin_DE
# 2       berlin                Paris  Air France        08:55     berlin_DE
# 3       berlin               Vienna    Austrian        08:55     berlin_DE
# 4       berlin    Frankfurt-am-Main   Lufthansa        08:55     berlin_DE
# ..         ...                  ...         ...          ...           ...
# 919  barcelona  Gran Canaria Island      Iberia        20:10  barcelona_ES
# 920  barcelona             Katowice    Wizz Air        19:50  barcelona_ES
# 921  barcelona            Bucharest    Blue Air        19:50  barcelona_ES
# 922  barcelona    Frankfurt-am-Main     Ryanair        19:50  barcelona_ES
# 923  barcelona               Kraków     Ryanair        20:00  barcelona_ES
#
# [924 rows x 5 columns]

# %%
arrivals_cities.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1272 entries, 0 to 1271
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   city               1272 non-null   object
#  1   airport_departure  1272 non-null   object
#  2   airline            1272 non-null   object
#  3   arrival_time       1272 non-null   object
#  4   city_iso           1272 non-null   object
# dtypes: object(5)
# memory usage: 49.8+ KB

# %% [markdown]
# <h>API</h><h1> Weather data and forecast with API</h1>

# %% [markdown]
# <h>API</h>

# %% [markdown]
# <h1>Berlin Weather and forecast with API</h1>

# %%
import requests

url = "https://community-open-weather-map.p.rapidapi.com/forecast"

querystring = {"q":"berlin,de,london,uk,barcellona,sp"}

headers = {
    'x-rapidapi-host': "community-open-weather-map.p.rapidapi.com",
    'x-rapidapi-key': api_key
    }

response = requests.request("GET", url, headers=headers, params=querystring)

print(response.text)
# Out:
# {"cod":"200","message":0,"cnt":40,"list":[{"dt":1638176400,"main":{"temp":275.16,"feels_like":271.7,"temp_min":274.72,"temp_max":275.16,"pressure":1000,"sea_level":1000,"grnd_level":997,"humidity":93,"temp_kf":0.44},"weather":[{"id":803,"main":"Clouds","description":"broken clouds","icon":"04d"}],"clouds":{"all":75},"wind":{"speed":3.47,"deg":286,"gust":5.64},"visibility":10000,"pop":0,"sys":{"pod":"d"},"dt_txt":"2021-11-29 09:00:00"},{"dt":1638187200,"main":{"temp":275.36,"feels_like":271.67,"temp_min":275.36,"temp_max":275.77,"pressure":1001,"sea_level":1001,"grnd_level":997,"humidity":89,"temp_kf":-0.41},"weather":[{"id":803,"main":"Clouds","description":"broken clouds","icon":"04d"}],"clouds":{"all":83},"wind":{"speed":3.86,"deg":290,"gust":6.44},"visibility":10000,"pop":0,"sys":{"pod":"d"},"dt_txt":"2021-11-29 12:00:00"},{"dt":1638198000,"main":{"temp":275.5,"feels_like":272.19,"temp_min":275.5,"temp_max":275.67,"pressure":1003,"sea_level":1003,"grnd_level":998,"humidity":85,"temp_kf":-0.17},"weather":[{"id":804,"main":"Clouds","description":"overcast clouds","icon":"04n"}],"clouds":{"all":87},"wind":{"speed":3.37,"deg":292,"gust":6.58},"visibility":10000,"pop":0,"sys":{"pod":"n"},"dt_txt":"2021-11-29 15:00:00"},{"dt":1638208800,"main":{"temp":274.65,"feels_like":271,"temp_min":274.65,"temp_max":274.65,"pressure":1005,"sea_level":1005,"grnd_level":1000,"humidity":93,"temp_kf":0},"weather":[{"id":804,"main":"Clouds","description":"overcast clouds","icon":"04n"}],"clouds":{"all":96},"wind":{"speed":3.58,"deg":312,"gust":6.24},"visibility":8688,"pop":0,"sys":{"pod":"n"},"dt_txt":"2021-11-29 18:00:00"},{"dt":1638219600,"main":{"temp":274.37,"feels_like":271.22,"temp_min":274.37,"temp_max":274.37,"pressure":1007,"sea_level":1007,"grnd_level":1001,"humidity":89,"temp_kf":0},"weather":[{"id":804,"main":"Clouds","description":"overcast clouds","icon":"04n"}],"clouds":{"all":100},"wind":{"speed":2.88,"deg":279,"gust":6.03},"visibility":10000,"pop":0.23,"sys":{"pod":"n"},"dt_txt":"2021-11-29 21:00:00"},{"dt":1638230400,"main":{"temp":274.42,"feels_like":270.71,"temp_min":274.42,"temp_max":274.42,"pressure":1007,"sea_level":1007,"grnd_level":1001,"humidity":88,"temp_kf":0},"weather":[{"id":804,"main":"Clouds","description":"overcast clouds","icon":"04n"}],"clouds":{"all":100},"wind":{"speed":3.59,"deg":256,"gust":9.08},"visibility":10000,"pop":0.13,"sys":{"pod":"n"},"dt_txt":"2021-11-30 00:00:00"},{"dt":1638241200,"main":{"temp":275.08,"feels_like":270.85,"temp_min":275.08,"temp_max":275.08,"pressure":1004,"sea_level":1004,"grnd_level":999,"humidity":89,"temp_kf":0},"weather":[{"id":804,"main":"Clouds","description":"overcast clouds","icon":"04n"}],"clouds":{"all":100},"wind":{"speed":4.64,"deg":237,"gust":10.44},"visibility":10000,"pop":0,"sys":{"pod":"n"},"dt_txt":"2021-11-30 03:00:00"},{"dt":1638252000,"main":{"temp":274.59,"feels_like":269.14,"temp_min":274.59,"temp_max":274.59,"pressure":1000,"sea_level":1000,"grnd_level":995,"humidity":96,"temp_kf":0},"weather":[{"id":600,"main":"Snow","description":"light snow","icon":"13n"}],"clouds":{"all":100},"wind":{"speed":6.86,"deg":216,"gust":15.4},"visibility":100,"pop":0.54,"snow":{"3h":0.73},"sys":{"pod":"n"},"dt_txt":"2021-11-30 06:00:00"},{"dt":1638262800,"main":{"temp":275.92,"feels_like":270.38,"temp_min":275.92,"temp_max":275.92,"pressure":996,"sea_level":996,"grnd_level":991,"humidity":95,"temp_kf":0},"weather":[{"id":500,"main":"Rain","description":"light rain","icon":"10d"}],"clouds":{"all":100},"wind":{"speed":8.12,"deg":252,"gust":18.08},"visibility":1826,"pop":1,"rain":{"3h":2.44},"sys":{"pod":"d"},"dt_txt":"2021-11-30 09:00:00"},{"dt":1638273600,"main":{"temp":278.64,"feels_like":273.91,"temp_min":278.64,"temp_max":278.64,"pressure":993,"sea_level":993,"grnd_level":988,"humidity":88,"temp_kf":0},"weather":[{"id":500,"main":"Rain","description":"light rain","icon":"10d"}],"clouds":{"all":100},"wind":{"speed":8.16,"deg":263,"gust":17.77},"visibility":10000,"pop":1,"rain": ...

# %%
import numpy as np

# %%
JSON(response.json())

# %%
weather_berlin=response.json()
weather_berlin['list'][0]['main']['temp']
weather_berlin['list'][0]['weather'][0]['main']
weather_berlin['list'][0]['weather'][0]['description']
weather_berlin['list'][0]['dt_txt']
# Out:
# '2021-11-29 09:00:00'

# %%
weather_berlin['list'][0]['main']['temp']
# Out:
# 275.16

# %%
from scipy.constants import convert_temperature
convert_temperature(np.array([275.16]),'Kelvin', 'Celsius')
# Out:
# array([2.01])

# %%
day=[]
time=[]
weather=[]
description_weather=[]
temp=[]
for i in range(len(weather_berlin['list'])):
    time.append(weather_berlin['list'][i]['dt_txt'][10:-3])
    day.append(weather_berlin['list'][i]['dt_txt'][:10])
    weather.append(weather_berlin['list'][i]['weather'][0]['main'])
    description_weather.append(weather_berlin['list'][i]['weather'][0]['description'])
    temp.append(weather_berlin['list'][0]['main']['temp'])

# %%
weather_berlin_5_days=pd.DataFrame({'city':'berlin','weather':weather,'description':description_weather,'time':time,'day':day,'temp':temp,'city_iso':'berlin_DE'})

# %%
weather_berlin_5_days['temp']= 2.01

# %%
weather_berlin_5_days.head()
# Out:
#      city weather      description    time         day  temp   city_iso
# 0  berlin  Clouds    broken clouds   09:00  2021-11-29  2.01  berlin_DE
# 1  berlin  Clouds    broken clouds   12:00  2021-11-29  2.01  berlin_DE
# 2  berlin  Clouds  overcast clouds   15:00  2021-11-29  2.01  berlin_DE
# 3  berlin  Clouds  overcast clouds   18:00  2021-11-29  2.01  berlin_DE
# 4  berlin  Clouds  overcast clouds   21:00  2021-11-29  2.01  berlin_DE

# %%
weather_berlin_5_days.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   city         40 non-null     object
#  1   weather      40 non-null     object
#  2   description  40 non-null     object
#  3   time         40 non-null     object
#  4   day          40 non-null     object
#  5   temp         40 non-null     float64
#  6   city_iso     40 non-null     object
# dtypes: float64(1), object(6)
# memory usage: 2.3+ KB

# %% [markdown]
# <h1>Paris Weather and forecast with API</h1>

# %%
import requests

url = "https://community-open-weather-map.p.rapidapi.com/forecast"

querystring = {"q":"paris,fr"}

headers = {
    'x-rapidapi-host': "community-open-weather-map.p.rapidapi.com",
    'x-rapidapi-key': api_key
    }

response = requests.request("GET", url, headers=headers, params=querystring)

print(response.text)
# Out:
# {"cod":"200","message":0,"cnt":40,"list":[{"dt":1638176400,"main":{"temp":273.86,"feels_like":270.56,"temp_min":273.86,"temp_max":276.35,"pressure":1013,"sea_level":1013,"grnd_level":1009,"humidity":93,"temp_kf":-2.49},"weather":[{"id":800,"main":"Clear","description":"clear sky","icon":"01d"}],"clouds":{"all":0},"wind":{"speed":2.93,"deg":312,"gust":9.22},"visibility":10000,"pop":0,"sys":{"pod":"d"},"dt_txt":"2021-11-29 09:00:00"},{"dt":1638187200,"main":{"temp":275.53,"feels_like":271.8,"temp_min":275.53,"temp_max":278.86,"pressure":1014,"sea_level":1014,"grnd_level":1010,"humidity":84,"temp_kf":-3.33},"weather":[{"id":800,"main":"Clear","description":"clear sky","icon":"01d"}],"clouds":{"all":6},"wind":{"speed":3.99,"deg":324,"gust":6.3},"visibility":10000,"pop":0.02,"sys":{"pod":"d"},"dt_txt":"2021-11-29 12:00:00"},{"dt":1638198000,"main":{"temp":277.31,"feels_like":274.93,"temp_min":277.31,"temp_max":279.04,"pressure":1015,"sea_level":1015,"grnd_level":1011,"humidity":70,"temp_kf":-1.73},"weather":[{"id":803,"main":"Clouds","description":"broken clouds","icon":"04d"}],"clouds":{"all":57},"wind":{"speed":2.65,"deg":303,"gust":5.75},"visibility":10000,"pop":0.01,"sys":{"pod":"d"},"dt_txt":"2021-11-29 15:00:00"},{"dt":1638208800,"main":{"temp":277.31,"feels_like":275.2,"temp_min":277.31,"temp_max":277.31,"pressure":1018,"sea_level":1018,"grnd_level":1013,"humidity":72,"temp_kf":0},"weather":[{"id":803,"main":"Clouds","description":"broken clouds","icon":"04n"}],"clouds":{"all":66},"wind":{"speed":2.34,"deg":279,"gust":6.24},"visibility":10000,"pop":0,"sys":{"pod":"n"},"dt_txt":"2021-11-29 18:00:00"},{"dt":1638219600,"main":{"temp":276.35,"feels_like":273.98,"temp_min":276.35,"temp_max":276.35,"pressure":1020,"sea_level":1020,"grnd_level":1015,"humidity":79,"temp_kf":0},"weather":[{"id":802,"main":"Clouds","description":"scattered clouds","icon":"03n"}],"clouds":{"all":49},"wind":{"speed":2.43,"deg":255,"gust":6.39},"visibility":10000,"pop":0,"sys":{"pod":"n"},"dt_txt":"2021-11-29 21:00:00"},{"dt":1638230400,"main":{"temp":275.88,"feels_like":272.46,"temp_min":275.88,"temp_max":275.88,"pressure":1020,"sea_level":1020,"grnd_level":1015,"humidity":79,"temp_kf":0},"weather":[{"id":802,"main":"Clouds","description":"scattered clouds","icon":"03n"}],"clouds":{"all":38},"wind":{"speed":3.64,"deg":236,"gust":10.08},"visibility":10000,"pop":0,"sys":{"pod":"n"},"dt_txt":"2021-11-30 00:00:00"},{"dt":1638241200,"main":{"temp":276.66,"feels_like":272.78,"temp_min":276.66,"temp_max":276.66,"pressure":1019,"sea_level":1019,"grnd_level":1015,"humidity":79,"temp_kf":0},"weather":[{"id":803,"main":"Clouds","description":"broken clouds","icon":"04n"}],"clouds":{"all":75},"wind":{"speed":4.7,"deg":230,"gust":12.33},"visibility":10000,"pop":0,"sys":{"pod":"n"},"dt_txt":"2021-11-30 03:00:00"},{"dt":1638252000,"main":{"temp":277.56,"feels_like":273.66,"temp_min":277.56,"temp_max":277.56,"pressure":1019,"sea_level":1019,"grnd_level":1014,"humidity":81,"temp_kf":0},"weather":[{"id":500,"main":"Rain","description":"light rain","icon":"10n"}],"clouds":{"all":87},"wind":{"speed":5.19,"deg":242,"gust":13.81},"visibility":10000,"pop":0.2,"rain":{"3h":0.24},"sys":{"pod":"n"},"dt_txt":"2021-11-30 06:00:00"},{"dt":1638262800,"main":{"temp":279,"feels_like":275.28,"temp_min":279,"temp_max":279,"pressure":1019,"sea_level":1019,"grnd_level":1014,"humidity":82,"temp_kf":0},"weather":[{"id":804,"main":"Clouds","description":"overcast clouds","icon":"04d"}],"clouds":{"all":99},"wind":{"speed":5.62,"deg":242,"gust":15.05},"visibility":10000,"pop":0,"sys":{"pod":"d"},"dt_txt":"2021-11-30 09:00:00"},{"dt":1638273600,"main":{"temp":280.25,"feels_like":276.69,"temp_min":280.25,"temp_max":280.25,"pressure":1018,"sea_level":1018,"grnd_level":1013,"humidity":82,"temp_kf":0},"weather":[{"id":804,"main":"Clouds","description":"overcast clouds","icon":"04d"}],"clouds":{"all":99},"wind":{"speed":6.06,"deg":244,"gust":14.82},"visibility":10000,"pop":0,"sys":{"pod":"d"},"dt_tx ...

# %%
JSON(response.json())

# %%
weather_paris=response.json()
weather_paris['list'][0]['main']['temp']
weather_paris['list'][0]['weather'][0]['main']
weather_paris['list'][0]['weather'][0]['description']
weather_paris['list'][0]['dt_txt']
# Out:
# '2021-11-29 09:00:00'

# %%
weather_paris['list'][0]['main']['temp']
# Out:
# 273.86

# %%
convert_temperature(np.array([273.86]),'Kelvin', 'Celsius')
# Out:
# array([0.71])

# %%
day=[]
time=[]
weather=[]
description_weather=[]
temp=[]
for i in range(len(weather_paris['list'])):
    time.append(weather_paris['list'][i]['dt_txt'][10:-3])
    day.append(weather_paris['list'][i]['dt_txt'][:10])
    weather.append(weather_paris['list'][i]['weather'][0]['main'])
    description_weather.append(weather_paris['list'][i]['weather'][0]['description'])
    temp.append(weather_paris['list'][0]['main']['temp'])

# %%
weather_paris_5_days=pd.DataFrame({'city':'paris','weather':weather,'description':description_weather,'time':time,'day':day,'temp':temp,'city_iso':'paris_FR'})

# %%
weather_paris_5_days['temp']=0.71

# %%
weather_paris_5_days.head()
# Out:
#     city weather       description    time         day  temp  city_iso
# 0  paris   Clear         clear sky   09:00  2021-11-29  0.71  paris_FR
# 1  paris   Clear         clear sky   12:00  2021-11-29  0.71  paris_FR
# 2  paris  Clouds     broken clouds   15:00  2021-11-29  0.71  paris_FR
# 3  paris  Clouds     broken clouds   18:00  2021-11-29  0.71  paris_FR
# 4  paris  Clouds  scattered clouds   21:00  2021-11-29  0.71  paris_FR

# %%
weather_paris_5_days.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   city         40 non-null     object
#  1   weather      40 non-null     object
#  2   description  40 non-null     object
#  3   time         40 non-null     object
#  4   day          40 non-null     object
#  5   temp         40 non-null     float64
#  6   city_iso     40 non-null     object
# dtypes: float64(1), object(6)
# memory usage: 2.3+ KB

# %% [markdown]
# <h1>Barcelona Weather and forecast with API</h1>

# %%
import requests

url = "https://community-open-weather-map.p.rapidapi.com/forecast"

querystring = {"q":"barcelona,es"}

headers = {
    'x-rapidapi-host': "community-open-weather-map.p.rapidapi.com",
    'x-rapidapi-key': api_key
    }

response = requests.request("GET", url, headers=headers, params=querystring)

print(response.text)
# Out:
# {"cod":"200","message":0,"cnt":40,"list":[{"dt":1638176400,"main":{"temp":277.88,"feels_like":274.63,"temp_min":277.88,"temp_max":280.85,"pressure":1011,"sea_level":1011,"grnd_level":1006,"humidity":75,"temp_kf":-2.97},"weather":[{"id":801,"main":"Clouds","description":"few clouds","icon":"02d"}],"clouds":{"all":20},"wind":{"speed":4.09,"deg":311,"gust":5.95},"visibility":10000,"pop":0,"sys":{"pod":"d"},"dt_txt":"2021-11-29 09:00:00"},{"dt":1638187200,"main":{"temp":279.9,"feels_like":277.22,"temp_min":279.9,"temp_max":283.93,"pressure":1011,"sea_level":1011,"grnd_level":1007,"humidity":61,"temp_kf":-4.03},"weather":[{"id":801,"main":"Clouds","description":"few clouds","icon":"02d"}],"clouds":{"all":13},"wind":{"speed":3.88,"deg":273,"gust":4.87},"visibility":10000,"pop":0,"sys":{"pod":"d"},"dt_txt":"2021-11-29 12:00:00"},{"dt":1638198000,"main":{"temp":282.59,"feels_like":281.47,"temp_min":282.59,"temp_max":284.94,"pressure":1012,"sea_level":1012,"grnd_level":1007,"humidity":50,"temp_kf":-2.35},"weather":[{"id":800,"main":"Clear","description":"clear sky","icon":"01d"}],"clouds":{"all":7},"wind":{"speed":2.28,"deg":235,"gust":3.41},"visibility":10000,"pop":0,"sys":{"pod":"d"},"dt_txt":"2021-11-29 15:00:00"},{"dt":1638208800,"main":{"temp":283.87,"feels_like":282.22,"temp_min":283.87,"temp_max":283.87,"pressure":1015,"sea_level":1015,"grnd_level":1010,"humidity":47,"temp_kf":0},"weather":[{"id":802,"main":"Clouds","description":"scattered clouds","icon":"03n"}],"clouds":{"all":27},"wind":{"speed":1.57,"deg":131,"gust":1.95},"visibility":10000,"pop":0,"sys":{"pod":"n"},"dt_txt":"2021-11-29 18:00:00"},{"dt":1638219600,"main":{"temp":282.54,"feels_like":280.03,"temp_min":282.54,"temp_max":282.54,"pressure":1019,"sea_level":1019,"grnd_level":1013,"humidity":57,"temp_kf":0},"weather":[{"id":802,"main":"Clouds","description":"scattered clouds","icon":"03n"}],"clouds":{"all":36},"wind":{"speed":4.87,"deg":58,"gust":4.76},"visibility":10000,"pop":0,"sys":{"pod":"n"},"dt_txt":"2021-11-29 21:00:00"},{"dt":1638230400,"main":{"temp":281.82,"feels_like":279.52,"temp_min":281.82,"temp_max":281.82,"pressure":1021,"sea_level":1021,"grnd_level":1015,"humidity":61,"temp_kf":0},"weather":[{"id":802,"main":"Clouds","description":"scattered clouds","icon":"03n"}],"clouds":{"all":26},"wind":{"speed":3.99,"deg":44,"gust":4.31},"visibility":10000,"pop":0,"sys":{"pod":"n"},"dt_txt":"2021-11-30 00:00:00"},{"dt":1638241200,"main":{"temp":281.51,"feels_like":279.74,"temp_min":281.51,"temp_max":281.51,"pressure":1022,"sea_level":1022,"grnd_level":1016,"humidity":61,"temp_kf":0},"weather":[{"id":802,"main":"Clouds","description":"scattered clouds","icon":"03n"}],"clouds":{"all":37},"wind":{"speed":2.92,"deg":14,"gust":3.01},"visibility":10000,"pop":0,"sys":{"pod":"n"},"dt_txt":"2021-11-30 03:00:00"},{"dt":1638252000,"main":{"temp":281.32,"feels_like":279.9,"temp_min":281.32,"temp_max":281.32,"pressure":1023,"sea_level":1023,"grnd_level":1017,"humidity":60,"temp_kf":0},"weather":[{"id":802,"main":"Clouds","description":"scattered clouds","icon":"03n"}],"clouds":{"all":28},"wind":{"speed":2.38,"deg":19,"gust":2.87},"visibility":10000,"pop":0,"sys":{"pod":"n"},"dt_txt":"2021-11-30 06:00:00"},{"dt":1638262800,"main":{"temp":282.55,"feels_like":281.95,"temp_min":282.55,"temp_max":282.55,"pressure":1025,"sea_level":1025,"grnd_level":1020,"humidity":59,"temp_kf":0},"weather":[{"id":803,"main":"Clouds","description":"broken clouds","icon":"04d"}],"clouds":{"all":63},"wind":{"speed":1.66,"deg":11,"gust":2.27},"visibility":10000,"pop":0,"sys":{"pod":"d"},"dt_txt":"2021-11-30 09:00:00"},{"dt":1638273600,"main":{"temp":284.17,"feels_like":282.79,"temp_min":284.17,"temp_max":284.17,"pressure":1025,"sea_level":1025,"grnd_level":1019,"humidity":56,"temp_kf":0},"weather":[{"id":803,"main":"Clouds","description":"broken clouds","icon":"04d"}],"clouds":{"all":77},"wind":{"speed":1.44,"deg":2,"gust":1.71},"visibility":10000,"pop":0,"sys":{"pod":"d"},"dt_txt":"2021-11-30 12:0 ...

# %%
JSON(response.json())

# %%
weather_barcelona=response.json()
weather_barcelona['list'][0]['main']['temp']
weather_barcelona['list'][0]['weather'][0]['main']
weather_barcelona['list'][0]['weather'][0]['description']
weather_barcelona['list'][0]['dt_txt']
# Out:
# '2021-11-29 09:00:00'

# %%
weather_barcelona['list'][0]['main']['temp']
# Out:
# 277.88

# %%
convert_temperature(np.array([277.88]),'Kelvin', 'Celsius')
# Out:
# array([4.73])

# %%
day=[]
time=[]
weather=[]
description_weather=[]
temp=[]
for i in range(len(weather_barcelona['list'])):
    time.append(weather_barcelona['list'][i]['dt_txt'][10:-3])
    day.append(weather_barcelona['list'][i]['dt_txt'][:10])
    weather.append(weather_barcelona['list'][i]['weather'][0]['main'])
    description_weather.append(weather_barcelona['list'][i]['weather'][0]['description'])
    temp.append(weather_barcelona['list'][0]['main']['temp'])

# %%
weather_barcelona_5_days=pd.DataFrame({'city':'barcelona','weather':weather,'description':description_weather,'time':time,'day':day,'temp':temp,'city_iso':'barcelona_ES'})

# %%
weather_barcelona_5_days['temp']=4.73

# %%
weather_barcelona_5_days.head()
# Out:
#         city weather       description    time         day  temp      city_iso
# 0  barcelona  Clouds        few clouds   09:00  2021-11-29  4.73  barcelona_ES
# 1  barcelona  Clouds        few clouds   12:00  2021-11-29  4.73  barcelona_ES
# 2  barcelona   Clear         clear sky   15:00  2021-11-29  4.73  barcelona_ES
# 3  barcelona  Clouds  scattered clouds   18:00  2021-11-29  4.73  barcelona_ES
# 4  barcelona  Clouds  scattered clouds   21:00  2021-11-29  4.73  barcelona_ES

# %%
weather_paris_5_days.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   city         40 non-null     object
#  1   weather      40 non-null     object
#  2   description  40 non-null     object
#  3   time         40 non-null     object
#  4   day          40 non-null     object
#  5   temp         40 non-null     float64
#  6   city_iso     40 non-null     object
# dtypes: float64(1), object(6)
# memory usage: 2.3+ KB

# %% [markdown]
# <h1>Cities Weather and forecast with API</h1>

# %%
weather_forecast_cities=weather_berlin_5_days.append([weather_paris_5_days,weather_barcelona_5_days]).reset_index()
weather_forecast_cities=weather_forecast_cities.drop('index', axis=1)
weather_forecast_cities
# Out:
#           city weather       description    time         day  temp  \
# 0       berlin  Clouds     broken clouds   09:00  2021-11-29  2.01
# 1       berlin  Clouds     broken clouds   12:00  2021-11-29  2.01
# 2       berlin  Clouds   overcast clouds   15:00  2021-11-29  2.01
# 3       berlin  Clouds   overcast clouds   18:00  2021-11-29  2.01
# 4       berlin  Clouds   overcast clouds   21:00  2021-11-29  2.01
# ..         ...     ...               ...     ...         ...   ...
# 115  barcelona  Clouds  scattered clouds   18:00  2021-12-03  4.73
# 116  barcelona  Clouds  scattered clouds   21:00  2021-12-03  4.73
# 117  barcelona  Clouds     broken clouds   00:00  2021-12-04  4.73
# 118  barcelona  Clouds   overcast clouds   03:00  2021-12-04  4.73
# 119  barcelona  Clouds   overcast clouds   06:00  2021-12-04  4.73
#
#          city_iso
# 0       berlin_DE
# 1       berlin_DE
# 2       berlin_DE
# 3       berlin_DE
# 4       berlin_DE
# ..            ...
# 115  barcelona_ES
# 116  barcelona_ES
# 117  barcelona_ES
# 118  barcelona_ES
# 119  barcelona_ES
#
# [120 rows x 7 columns]

# %%
weather_forecast_cities.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120 entries, 0 to 119
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   city         120 non-null    object
#  1   weather      120 non-null    object
#  2   description  120 non-null    object
#  3   time         120 non-null    object
#  4   day          120 non-null    object
#  5   temp         120 non-null    float64
#  6   city_iso     120 non-null    object
# dtypes: float64(1), object(6)
# memory usage: 6.7+ KB

# %% [markdown]
# <h1>Update data into database</h1>

# %% [markdown]
# #### Establish the connection

# %%
# !pip install sqlalchemy
# Out:
# Requirement already satisfied: sqlalchemy in /Users/sabrinamarano/opt/anaconda3/lib/python3.8/site-packages (1.4.7)
# Requirement already satisfied: greenlet!=0.4.17 in /Users/sabrinamarano/opt/anaconda3/lib/python3.8/site-packages (from sqlalchemy) (1.0.0)

# %%
# !pip install pymysql
# Out:
# Collecting pymysql
#   Downloading PyMySQL-1.0.2-py3-none-any.whl (43 kB)
#      |████████████████████████████████| 43 kB 3.0 MB/s eta 0:00:011
# Installing collected packages: pymysql
# Successfully installed pymysql-1.0.2

# %%
import pandas as pd
import sqlalchemy
import pymysql

# %%
from keys import *

# %%
schema="gans"
host="127.0.0.1"
user="root"
password='procione91'
port=3306
con = f'mysql+pymysql://{user}:{password}@{host}:{port}/{schema}'
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-75-7b113ba3e0e1> in <module>
#       2 host="127.0.0.1"
#       3 user="root"
# ----> 4 password=my_password
#       5 port=3306
#       6 con = f'mysql+pymysql://{user}:{password}@{host}:{port}/{schema}'
#
# NameError: name 'my_password' is not defined

# %% [markdown]
# <h1>CREATE CONNECTION DATAFRAMES TO DATABASE</h1>

# %%
cities.to_sql('cities', if_exists='append', con=con, index=False)
# Out:
# ---------------------------------------------------------------------------
# IntegrityError                            Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1684                 if not evt_handled:
# -> 1685                     self.dialect.do_executemany(
#    1686                         cursor, statement, parameters, context
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/dialects/mysql/mysqldb.py in do_executemany(self, cursor, statement, parameters, context)
#     147     def do_executemany(self, cursor, statement, parameters, context=None):
# --> 148         rowcount = cursor.executemany(statement, parameters)
#     149         if context is not None:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pymysql/cursors.py in executemany(self, query, args)
#     172             assert q_values[0] == "(" and q_values[-1] == ")"
# --> 173             return self._do_execute_many(
#     174                 q_prefix,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pymysql/cursors.py in _do_execute_many(self, prefix, values, postfix, args, max_stmt_length, encoding)
#     210             sql += v
# --> 211         rows += self.execute(sql + postfix)
#     212         self.rowcount = rows
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pymysql/cursors.py in execute(self, query, args)
#     147
# --> 148         result = self._query(query)
#     149         self._executed = query
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pymysql/cursors.py in _query(self, q)
#     309         self._clear_result()
# --> 310         conn.query(q)
#     311         self._do_get_result()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pymysql/connections.py in query(self, sql, unbuffered)
#     547         self._execute_command(COMMAND.COM_QUERY, sql)
# --> 548         self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#     549         return self._affected_rows
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pymysql/connections.py in _read_query_result(self, unbuffered)
#     774             result = MySQLResult(self)
# --> 775             result.read()
#     776         self._result = result
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pymysql/connections.py in read(self)
#    1155         try:
# -> 1156             first_packet = self.connection._read_packet()
#    1157
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pymysql/connections.py in _read_packet(self, packet_type)
#     724                 self._result.unbuffered_active = False
# --> 725             packet.raise_for_error()
#     726         return packet
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pymysql/protocol.py in raise_for_error(self)
#     220             print("errno =", errno)
# --> 221         err.raise_mysql_exception(self._data)
#     222
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pymysql/err.py in raise_mysql_exception(data)
#     142         errorclass = InternalError if errno < 1000 else OperationalError
# --> 143     raise errorclass(errno, errval)
#
# IntegrityError: (1062, "Duplicate entry 'berlin_DE' for key 'cities.PRIMARY'")
#
# The above exception was the direct cause of the following exception:
#
# IntegrityError                            Traceback (most recent call last)
# <ipython-input-69-eaf1a68aa63f> in <module>
# ----> 1 cities.to_sql('cities', if_exists='append', con=con, index=False)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2777         from pandas.io import sql
#    2778
# -> 2779         sql.to_sql(
#    2780             self,
#    2781             name,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/io/sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#     599         )
#     600
# --> 601     pandas_sql.to_sql(
#     602         frame,
#     603         name,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/io/sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method)
#    1417                 raise ValueError("inf cannot be used with MySQL") from err
#    1418             else:
# -> 1419                 raise err
#    1420
#    1421         if not name.isdigit() and not name.islower():
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/io/sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method)
#    1409
#    1410         try:
# -> 1411             table.insert(chunksize, method=method)
#    1412         except exc.SQLAlchemyError as err:
#    1413             # GH34431
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/io/sql.py in insert(self, chunksize, method)
#     843
#     844                 chunk_iter = zip(*[arr[start_i:end_i] for arr in data_list])
# --> 845                 exec_insert(conn, keys, chunk_iter)
#     846
#     847     def _query_iterator(
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/io/sql.py in _execute_insert(self, conn, keys, data_iter)
#     760         """
#     761         data = [dict(zip(keys, row)) for row in data_iter]
# --> 762         conn.execute(self.table.insert(), data)
#     763
#     764     def _execute_insert_multi(self, conn, keys, data_iter):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/base.py in execute(self, statement, *multiparams, **params)
#    1198             )
#    1199         else:
# -> 1200             return meth(self, multiparams, params, _EMPTY_EXECUTION_OPTS)
#    1201
#    1202     def _execute_function(self, func, multiparams, params, execution_options):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/sql/elements.py in _execute_on_connection(self, connection, multiparams, params, execution_options, _force)
#     311     ):
#     312         if _force or self.supports_execution:
# --> 313             return connection._execute_clauseelement(
#     314                 self, multiparams, params, execution_options
#     315             )
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/base.py in _execute_clauseelement(self, elem, multiparams, params, execution_options)
#    1387             linting=self.dialect.compiler_linting | compiler.WARN_LINTING,
#    1388         )
# -> 1389         ret = self._execute_context(
#    1390             dialect,
#    1391             dialect.execution_ctx_cls._init_compiled,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1746
#    1747         except BaseException as e:
# -> 1748             self._handle_dbapi_exception(
#    1749                 e, statement, parameters, cursor, context
#    1750             )
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    1927                 util.raise_(newraise, with_traceback=exc_info[2], from_=e)
#    1928             elif should_wrap:
# -> 1929                 util.raise_(
#    1930                     sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    1931                 )
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/util/compat.py in raise_(***failed resolving arguments***)
#     209
#     210         try:
# --> 211             raise exception
#     212         finally:
#     213             # credit to
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1683                             break
#    1684                 if not evt_handled:
# -> 1685                     self.dialect.do_executemany(
#    1686                         cursor, statement, parameters, context
#    1687                     )
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/dialects/mysql/mysqldb.py in do_executemany(self, cursor, statement, parameters, context)
#     146
#     147     def do_executemany(self, cursor, statement, parameters, context=None):
# --> 148         rowcount = cursor.executemany(statement, parameters)
#     149         if context is not None:
#     150             context._rowcount = rowcount
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pymysql/cursors.py in executemany(self, query, args)
#     171             q_postfix = m.group(3) or ""
#     172             assert q_values[0] == "(" and q_values[-1] == ")"
# --> 173             return self._do_execute_many(
#     174                 q_prefix,
#     175                 q_values,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pymysql/cursors.py in _do_execute_many(self, prefix, values, postfix, args, max_stmt_length, encoding)
#     209                 sql += b","
#     210             sql += v
# --> 211         rows += self.execute(sql + postfix)
#     212         self.rowcount = rows
#     213         return rows
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pymysql/cursors.py in execute(self, query, args)
#     146         query = self.mogrify(query, args)
#     147
# --> 148         result = self._query(query)
#     149         self._executed = query
#     150         return result
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pymysql/cursors.py in _query(self, q)
#     308         self._last_executed = q
#     309         self._clear_result()
# --> 310         conn.query(q)
#     311         self._do_get_result()
#     312         return self.rowcount
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pymysql/connections.py in query(self, sql, unbuffered)
#     546             sql = sql.encode(self.encoding, "surrogateescape")
#     547         self._execute_command(COMMAND.COM_QUERY, sql)
# --> 548         self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#     549         return self._affected_rows
#     550
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pymysql/connections.py in _read_query_result(self, unbuffered)
#     773         else:
#     774             result = MySQLResult(self)
# --> 775             result.read()
#     776         self._result = result
#     777         if result.server_status is not None:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pymysql/connections.py in read(self)
#    1154     def read(self):
#    1155         try:
# -> 1156             first_packet = self.connection._read_packet()
#    1157
#    1158             if first_packet.is_ok_packet():
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pymysql/connections.py in _read_packet(self, packet_type)
#     723             if self._result is not None and self._result.unbuffered_active is True:
#     724                 self._result.unbuffered_active = False
# --> 725             packet.raise_for_error()
#     726         return packet
#     727
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pymysql/protocol.py in raise_for_error(self)
#     219         if DEBUG:
#     220             print("errno =", errno)
# --> 221         err.raise_mysql_exception(self._data)
#     222
#     223     def dump(self):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pymysql/err.py in raise_mysql_exception(data)
#     141     if errorclass is None:
#     142         errorclass = InternalError if errno < 1000 else OperationalError
# --> 143     raise errorclass(errno, errval)
#
# IntegrityError: (pymysql.err.IntegrityError) (1062, "Duplicate entry 'berlin_DE' for key 'cities.PRIMARY'")
# [SQL: INSERT INTO cities (city, iso, city_iso) VALUES (%(city)s, %(iso)s, %(city_iso)s)]
# [parameters: ({'city': 'berlin', 'iso': 'DE', 'city_iso': 'berlin_DE'}, {'city': 'paris', 'iso': 'FR', 'city_iso': 'paris_FR'}, {'city': 'barcelona', 'iso': 'ES', 'city_iso': 'barcelona_ES'})]
# (Background on this error at: http://sqlalche.me/e/14/gkpj)

# %%
pd.read_sql(
    sql = """
        select * from cities
    """,
    con = con
)
# Out:
#         city iso      city_iso
# 0  barcelona  ES  barcelona_ES
# 1     berlin  DE     berlin_DE
# 2      paris  FR      paris_FR

# %%
weather_forecast_cities.to_sql('weather_forecast_cities', if_exists='append', con=con, index=False)

# %%
pd.read_sql(
    sql = """
        select * from weather_forecast_cities
    """,
    con = con
)
# Out:
#      weather_id       city weather    description    time         day   temp  \
# 0           241     berlin   Clear      clear sky   12:00  2021-11-26    7.0
# 1           242     berlin   Clear      clear sky   15:00  2021-11-26    7.0
# 2           243     berlin  Clouds     few clouds   18:00  2021-11-26    7.0
# 3           244     berlin  Clouds  broken clouds   21:00  2021-11-26    7.0
# 4           245     berlin  Clouds  broken clouds   00:00  2021-11-27    7.0
# ..          ...        ...     ...            ...     ...         ...    ...
# 115         356  barcelona   Clear      clear sky   21:00  2021-11-30  284.0
# 116         357  barcelona   Clear      clear sky   00:00  2021-12-01  284.0
# 117         358  barcelona   Clear      clear sky   03:00  2021-12-01  284.0
# 118         359  barcelona   Clear      clear sky   06:00  2021-12-01  284.0
# 119         360  barcelona  Clouds     few clouds   09:00  2021-12-01  284.0
#
#          city_iso
# 0       berlin_DE
# 1       berlin_DE
# 2       berlin_DE
# 3       berlin_DE
# 4       berlin_DE
# ..            ...
# 115  barcelona_ES
# 116  barcelona_ES
# 117  barcelona_ES
# 118  barcelona_ES
# 119  barcelona_ES
#
# [120 rows x 8 columns]

# %%
arrivals_cities.to_sql('arrivals_cities', if_exists='append', con=con, index=False)

# %%
pd.read_sql(
    sql = """
        select * from arrivals_cities
    """,
    con = con
)
# Out:
#       arrivals_id       city    airport_departure         airline  \
# 0               1     berlin    Palma De Mallorca      Air France
# 1               2     berlin    Palma De Mallorca  Etihad Airways
# 2               3     berlin    Palma De Mallorca             KLM
# 3               4     berlin    Palma De Mallorca      Air Serbia
# 4               5     berlin             Alicante          Iberia
# ...           ...        ...                  ...             ...
# 1267         1268  barcelona    Frankfurt-am-Main         Ryanair
# 1268         1269  barcelona               Kraków         Ryanair
# 1269         1270  barcelona  Gran Canaria Island          Iberia
# 1270         1271  barcelona             Katowice        Wizz Air
# 1271         1272  barcelona            Bucharest        Blue Air
#
#      arrival_time      city_iso
# 0           07:55     berlin_DE
# 1           07:55     berlin_DE
# 2           07:55     berlin_DE
# 3           07:55     berlin_DE
# 4           08:10     berlin_DE
# ...           ...           ...
# 1267        19:50  barcelona_ES
# 1268        20:00  barcelona_ES
# 1269        20:10  barcelona_ES
# 1270        19:50  barcelona_ES
# 1271        19:50  barcelona_ES
#
# [1272 rows x 6 columns]

# %%
population_cities.to_sql('population_cities', if_exists='append', con=con, index=False)

# %%
pd.read_sql(
    sql = """
        select * from population_cities
    """,
    con = con
)
# Out:
#     population_id    age_range   value  perc       city      city_iso
# 0               1    0 - 2 age  141646     3      paris      paris_FR
# 1               2    3 - 5 age  161953     3      paris      paris_FR
# 2               3   6 - 11 age  360186     5      paris      paris_FR
# 3               4  12 - 17 age  363824     5      paris      paris_FR
# 4               5  18 - 24 age  409829     7      paris      paris_FR
# 5               6  25 - 34 age  693809    17      paris      paris_FR
# 6               7  35 - 44 age  915718    14      paris      paris_FR
# 7               8  45 - 54 age  903528    13      paris      paris_FR
# 8               9  55 - 64 age  705570    13      paris      paris_FR
# 9              10  65 - 74 age  547627     9      paris      paris_FR
# 10             11     75 e più  539712    10      paris      paris_FR
# 11             12    0 - 2 age  141646     3     berlin     berlin_DE
# 12             13    3 - 5 age  161953     3     berlin     berlin_DE
# 13             14   6 - 11 age  360186     5     berlin     berlin_DE
# 14             15  12 - 17 age  363824     5     berlin     berlin_DE
# 15             16  18 - 24 age  409829     7     berlin     berlin_DE
# 16             17  25 - 34 age  693809    17     berlin     berlin_DE
# 17             18  35 - 44 age  915718    14     berlin     berlin_DE
# 18             19  45 - 54 age  903528    13     berlin     berlin_DE
# 19             20  55 - 64 age  705570    13     berlin     berlin_DE
# 20             21  65 - 74 age  547627     9     berlin     berlin_DE
# 21             22     75 e più  539712    10     berlin     berlin_DE
# 22             23    0 - 2 age  141646     2  barcelona  barcelona_ES
# 23             24    3 - 5 age  161953     3  barcelona  barcelona_ES
# 24             25   6 - 11 age  360186     6  barcelona  barcelona_ES
# 25             26  12 - 17 age  363824     6  barcelona  barcelona_ES
# 26             27  18 - 24 age  409829     7  barcelona  barcelona_ES
# 27             28  25 - 34 age  693809    12  barcelona  barcelona_ES
# 28             29  35 - 44 age  915718    16  barcelona  barcelona_ES
# 29             30  45 - 54 age  903528    16  barcelona  barcelona_ES
# 30             31  55 - 64 age  705570    12  barcelona  barcelona_ES
# 31             32  65 - 74 age  547627    10  barcelona  barcelona_ES
# 32             33     75 e più  539712     9  barcelona  barcelona_ES

# %% [markdown]
# <h1>CREATE CONNECTION DATAFRAMES TO DATABASE AWS</h1>

# %%
schema="gans"
host="wbs-project3-db.cot1oigahvlu.us-east-2.rds.amazonaws.com"
user="admin"
password='mypasswordsabrina2021'
port=3306
con = f'mysql+pymysql://{user}:{password}@{host}:{port}/{schema}'

# %%
cities.to_sql('cities', if_exists='append', con=con, index=False)

# %%
pd.read_sql(
    sql = """
        select * from cities
    """,
    con = con
)
# Out:
#         city iso      city_iso
# 0  barcelona  ES  barcelona_ES
# 1     berlin  DE     berlin_DE
# 2      paris  FR      paris_FR

# %%
weather_forecast_cities.to_sql('weather_forecast_cities', if_exists='append', con=con, index=False)

# %%
pd.read_sql(
    sql = """
        select * from weather_forecast_cities
    """,
    con = con
)
# Out:
#      weather_id       city weather       description    time         day  \
# 0             1     berlin  Clouds     broken clouds   09:00  2021-11-29
# 1             2     berlin  Clouds     broken clouds   12:00  2021-11-29
# 2             3     berlin  Clouds   overcast clouds   15:00  2021-11-29
# 3             4     berlin  Clouds   overcast clouds   18:00  2021-11-29
# 4             5     berlin  Clouds   overcast clouds   21:00  2021-11-29
# ..          ...        ...     ...               ...     ...         ...
# 115         116  barcelona  Clouds  scattered clouds   18:00  2021-12-03
# 116         117  barcelona  Clouds  scattered clouds   21:00  2021-12-03
# 117         118  barcelona  Clouds     broken clouds   00:00  2021-12-04
# 118         119  barcelona  Clouds   overcast clouds   03:00  2021-12-04
# 119         120  barcelona  Clouds   overcast clouds   06:00  2021-12-04
#
#      temp      city_iso
# 0     2.0     berlin_DE
# 1     2.0     berlin_DE
# 2     2.0     berlin_DE
# 3     2.0     berlin_DE
# 4     2.0     berlin_DE
# ..    ...           ...
# 115   5.0  barcelona_ES
# 116   5.0  barcelona_ES
# 117   5.0  barcelona_ES
# 118   5.0  barcelona_ES
# 119   5.0  barcelona_ES
#
# [120 rows x 8 columns]

# %%
arrivals_cities.to_sql('arrivals_cities', if_exists='append', con=con, index=False)

# %%
pd.read_sql(
    sql = """
        select * from arrivals_cities
    """,
    con = con
)
# Out:
#      arrivals_id       city    airport_departure     airline arrival_time  \
# 0              1     berlin             Belgrade  Air Serbia        09:00
# 1              2     berlin               Zurich       SWISS        08:45
# 2              3     berlin                Paris  Air France        08:55
# 3              4     berlin               Vienna    Austrian        08:55
# 4              5     berlin    Frankfurt-am-Main   Lufthansa        08:55
# ..           ...        ...                  ...         ...          ...
# 919          920  barcelona  Gran Canaria Island      Iberia        20:10
# 920          921  barcelona             Katowice    Wizz Air        19:50
# 921          922  barcelona            Bucharest    Blue Air        19:50
# 922          923  barcelona    Frankfurt-am-Main     Ryanair        19:50
# 923          924  barcelona               Kraków     Ryanair        20:00
#
#          city_iso
# 0       berlin_DE
# 1       berlin_DE
# 2       berlin_DE
# 3       berlin_DE
# 4       berlin_DE
# ..            ...
# 919  barcelona_ES
# 920  barcelona_ES
# 921  barcelona_ES
# 922  barcelona_ES
# 923  barcelona_ES
#
# [924 rows x 6 columns]

# %%
population_cities.to_sql('population_cities', if_exists='append', con=con, index=False)

# %%
pd.read_sql(
    sql = """
        select * from population_cities
    """,
    con = con
)
# Out:
#     population_id    age_range   value  perc       city      city_iso
# 0               1    0 - 2 age   65309     3      paris      paris_FR
# 1               2    3 - 5 age   59827     3      paris      paris_FR
# 2               3   6 - 11 age  119576     5      paris      paris_FR
# 3               4  12 - 17 age  118412     5      paris      paris_FR
# 4               5  18 - 24 age  229742     7      paris      paris_FR
# 5               6  25 - 34 age  408704    17      paris      paris_FR
# 6               7  35 - 44 age  301547    14      paris      paris_FR
# 7               8  45 - 54 age  278738    13      paris      paris_FR
# 8               9  55 - 64 age  240245    13      paris      paris_FR
# 9              10  65 - 74 age  195095     9      paris      paris_FR
# 10             11     75 e più  170331    10      paris      paris_FR
# 11             12    0 - 2 age  116834     3     berlin     berlin_DE
# 12             13    3 - 5 age  112940     3     berlin     berlin_DE
# 13             14   6 - 11 age  196587     5     berlin     berlin_DE
# 14             15  12 - 17 age  179513     5     berlin     berlin_DE
# 15             16  18 - 24 age  264084     7     berlin     berlin_DE
# 16             17  25 - 34 age  613696    17     berlin     berlin_DE
# 17             18  35 - 44 age  530715    14     berlin     berlin_DE
# 18             19  45 - 54 age  482906    13     berlin     berlin_DE
# 19             20  55 - 64 age  466691    13     berlin     berlin_DE
# 20             21  65 - 74 age  325994     9     berlin     berlin_DE
# 21             22     75 e più  379531    10     berlin     berlin_DE
# 22             23    0 - 2 age  141646     2  barcelona  barcelona_ES
# 23             24    3 - 5 age  161953     3  barcelona  barcelona_ES
# 24             25   6 - 11 age  360186     6  barcelona  barcelona_ES
# 25             26  12 - 17 age  363824     6  barcelona  barcelona_ES
# 26             27  18 - 24 age  409829     7  barcelona  barcelona_ES
# 27             28  25 - 34 age  693809    12  barcelona  barcelona_ES
# 28             29  35 - 44 age  915718    16  barcelona  barcelona_ES
# 29             30  45 - 54 age  903528    16  barcelona  barcelona_ES
# 30             31  55 - 64 age  705570    12  barcelona  barcelona_ES
# 31             32  65 - 74 age  547627    10  barcelona  barcelona_ES
# 32             33     75 e più  539712     9  barcelona  barcelona_ES
